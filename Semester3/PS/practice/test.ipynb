# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Test Message

# %%
import pandas as pd

data = {
    'Product_ID': range(101, 111),
    'Product_Name': ['Product' + str(i) for i in range(1, 11)],
    'Category': ['Categ' + str(i) for i in range(1, 11)],
    'Price': [100*i for i in range(1, 11)],
    'Stock': [50 + 5*i for i in range(1, 11)]
}

df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Price'], df['Stock'])
